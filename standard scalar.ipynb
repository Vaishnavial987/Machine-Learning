# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd

# %%
'''fit_transform()  #it is used for trained data and to train the model it learns and transform the values based on based on mean snd standard deviation.``
transform()'''    #it is used for test data
# Out:
# 'fit_transform()  #it is used for trained data and to train the model it learns and transform the values based on based on mean snd standard deviation.``\ntransform()'

# %%
df=pd.DataFrame({'age':[23,34,44,46,57],'salary':[20000,30000,40000,50000,60000]})

# %%
scaler=StandardScaler(copy=False)

# %%
xtrain_scaled=scaler.fit_transform(df)
xtrain_scaled
# Out:
# array([[-1.54601518, -1.41421356],
#        [-0.59061254, -0.70710678],
#        [ 0.27793531,  0.        ],
#        [ 0.45164488,  0.70710678],
#        [ 1.40704753,  1.41421356]])

# %%
scaler.mean_
# Out:
# array([   40.8, 40000. ])

# %%
scaler.scale_
# Out:
# array([1.15134704e+01, 1.41421356e+04])

# %%
df1=pd.DataFrame({'age':[23,34,44,46,57],'salary':[20000,30000,40000,50000,60000],'price_in_lac':[2,3,4,5,6]})
df1
# Out:
#    age  salary  price_in_lac
# 0   23   20000             2
# 1   34   30000             3
# 2   44   40000             4
# 3   46   50000             5
# 4   57   60000             6

# %%
x=df1[['age','salary']]
y=df1['price_in_lac']

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,train_size=0.8,random_state=42)

# %%
scaler.transform(xtest)   #it accepts 2D
# Out:
# array([[-0.59061254, -0.70710678]])
